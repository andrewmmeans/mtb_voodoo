# %%
import requests
from lxml import html

session_requests = requests.session()

login_url = 'https://www.trailforks.com/login/'
result = session_requests.get(login_url)

tree = html.fromstring(result.text)

# %%
authenticity_token = list(set(tree.xpath("//input[@name='_token']/@value")))[0]

# %%
from os.path import join, dirname
from dotenv import load_dotenv

dotenv_path = join(dirname('.'), '.env')
 
# Load file from the path.
load_dotenv(dotenv_path)
# Out:
# True

# %%
import os

payload = {
    'username':os.getenv('TF_USER'),
    'password':os.getenv('TF_PASS')
}

# %%
r = requests.post(login_url, cookies=payload)

# %%
with requests.Session() as s:
    p = s.post(login_url, cookies=payload)
    # print the html returned or something more intelligent to see if it's a successful login page.
    print(p.text)

    # An authorised request.
    r = s.get('https://www.trailforks.com/trails/bootcamp/gpx/')
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
# <head>
# <title>Login to Trailforks | Trailforks</title>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta property="og:image" content="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_avatar.png"/>
# <meta property="og:site_name" content="Trailforks" />
# <meta property="fb:app_id" content="158879950980488" />
# <meta property="fb:admins" content="517713210" />
# <meta name="application-name" content="Trailforks" />
# <meta name="apple-itunes-app" content="app-id=987986743" />
# <meta name="theme-color" content="#fec200"/>
# <link rel="manifest" href="/manifest.json">
# <link rel="dns-prefetch" href="//es.pinkbike.org" />
# <link rel="dns-prefetch" href="//ep1.pinkbike.org" />
# <link rel="dns-prefetch" href="//ep2.pinkbike.org" />
# <link rel="dns-prefetch" href="//ep3.pinkbike.org" />
# <link rel="dns-prefetch" href="//ep4.pinkbike.org" />
# <link rel="dns-prefetch" href="//gis.pinkbike.org" />
# <link rel="publisher" href="https://plus.google.com/+Trailforksapp/" />
# <link rel="shortcut icon" href="https://es.pinkbike.org/246/sprt/i/trailforks/favicon.ico" />
# <link rel="apple-touch-icon" href="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_icon_120x120.png" />
# <link rel="apple-touch-icon-precomposed" href="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_icon_120x120p.png" />
#         <link rel="stylesheet" href="https://es.pinkbike.org/63d80940ad/sprt/c/trailforks/_common-min.css"/>
#         <script src="https://es.pinkbike.org/032616ad06c5ac/sprt/j/jquery.min.js"  crossorigin></script>
#                 <script type="text/javascript">
#         var _trackJs = {
#             customer: 'd979e0ee0b27484c936d70bfdc85dd4e'
#         };
#         var pbwww="https://www.trailforks.com/";
#         var pbxv="https://ev1.pinkbike.org/";
#         var pbdomain="trailforks.com";
#         var pbcs="https://es.pinkbike.org/246/sprt/i/";
#         var pbjs="https://es.pinkbike.org/326/sprt/j/";
#         var pbcookiedomain=".trailforks.com";
#         var pbuid='0';
#         </script>
#                 <script src="https://es.pinkbike.org/0326779e00d23d/sprt/j/pblib.js"  crossorigin></script>
#                 <script src="https://es.pinkbike.org/0326060dcf1c39/sprt/j/jquery-ui-1.10.3.custom.min.js"  crossorigin></script>
#
# <script>
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# ga('create', {
#   trackingId: 'UA-2380007-4',
#   cookieDomain: 'trailforks.com'
# });
# ga('send', 'pageview');
# </script>
#
# <script async src='https://www.google-analytics.com/analytics.js'></script>
# </head>
# <body id="top" class=" admin_debug">
# <a class="none" href="#content-container">[Skip to Content]</a>
#
# <div id="container">
#     <div id="container2">
#                     <div id="headerwrapper">
#         <div class="wrapper">
#             <header id="header" class="clearfix">
#                 <a href="https://www.trailforks.com/" id="logo">
#                     <img src="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_logo_vector_2color.svg" onerror="this.onerror=null; this.src='https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_logo_sign.png'" alt="Trailforks" width="227" height="35" />
#                 </a>
#                 <div id="header_left">
#                                         <div id="activitytype_menu" class="hovertip" title="Mountain Bike" onclick="ga('send', 'event', 'activitytype', 'header');">
#                         <div class="parent clickable grey" data-featherlight="https://www.trailforks.com/change_activitytype/?popup=1">
#                              <span aria-hidden="true" data-icon="&#xe90c;" class="activityIcon" title="Mountain Bike" style="color: #29691f;"></span>                             <span class="mobile_hide">Mountain Bike</span> <span class="openarrow">&nbsp;</span>
#                         </div>
#                     </div>
#                                             <a href="https://www.trailforks.com/pro/?source=header" class="getpro small tablet_hide">Get PRO</a>
#                                     </div>
#
#                 <div id="header_right">
#
#                     <div id="header_search">
#                         <form class="formCustom " name="search" action="/wosFormCheck.php" method="post"  >
# <div><input type="hidden" name="ripformname" value="search" /></div><input type="hidden" name="formpage"  value="/login/#search" /> <label for="search" class="none">Search site content</label><input type="hidden" name="fieldstack[0]" value="search" /><input type="text" name="search-lt100-textbasic" id="search"  autocomplete="off" placeholder="Search for Trails, Regions, etc..." value=""/> <input type="submit" name="submitbutton['search']"  value="search" onclick="if(typeof(wO) !== 'undefined') { return false; } else { wO=1;return true;}" /><input type="hidden" name="buttondest['search']" value="https://www.trailforks.com/x_search/" /> <input type="text" name="iebug" value="1" style="display:none" /><input type="hidden" name="formhash" value="+t9UzozQkiKVu3yg/RbklC9HNSiKn+sa+TLfOLz7KXUgV90dVS1i3nU+fLrvYLeAHg4mRyqAst+MLHtz8HDsfXb97UtnYYQPRVg7P9U=" autocomplete="off" /></form>                        <span id="searchicon" class="none clickable" aria-hidden="true" data-icon="&#xe986;"></span>
#                         <div id="search_results"></div>
#                     </div>
#
#                     <div id="user_menu">
#                         <div id="login" class="bold">
#     <ul id="loginLinks" class="inline">
#                     <li><span onclick="tflink('https://www.trailforks.com/login/')" class="clickable">login</span></li>
#             </ul>
# </div>                    </div>
#                 </div>
#             </header>
#         </div>
#     </div>
# <div id="navwrapper">
#     <div class="wrapper">
#         <nav id="navigation">
#             <ul id="menu" class="clearfix">
#                 <li id="menu_nearby" class="overflow">
#                     <a href="javascript:;" class="parent drop2">Nearby<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 250px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/nearby/">Nearby Overview</a></li>
#                             <li><a href="https://www.trailforks.com/map/">Fullscreen Map</a></li>
#                         </ul>
#                         <div class="padding10 greybox">
#                             <div id="nearbyRegions" class="menuDarkLinks"></div>
#                         </div>
#                     </div>
#                 </li>
#                 <li id="menu_trails">
#                     <a href="javascript:;" class="parent ">Trails<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 300px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/trails/">Browse by List</a></li>
#                             <li><a href="https://www.trailforks.com/trails/map/">Browse by Map</a></li>
#                             <li><a href="https://www.trailforks.com/regions/directory/">Region Directory</a></li>
#                                                         <li><a href="https://www.trailforks.com/region/united-kingdom/">United Kingdom Trails</a></li>
#                                                         <li class="yellow"><a href="https://www.trailforks.com/contribute/trail/" rel="nofollow">Add Trail</a></li>
#                         </ul>
#                                             </div>
#                 </li>
#                 <li id="menu_routes">
#                     <a href="javascript:;" class="parent ">Routes<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 190px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/routes/">Routes Overview</a></li>
#                             <li><a href="https://www.trailforks.com/routes/discover/">Recommended Routes</a></li>
#                             <li><a href="https://www.trailforks.com/ridelog/finder/">Route Finder</a></li>
#                             <li><a href="https://www.trailforks.com/ridelog/planner/">Route Planner</a></li>
#                                                             <li><a href="https://www.trailforks.com/routes/myroutes/">Manage My Routes</a></li>
#                                                         <li class="yellow"><a href="https://www.trailforks.com/contribute/route/" rel="nofollow">Create a Route</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                 <li id="menu_reports" class="overflow"><a href="javascript:;" class="parent drop2">Reports<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 170px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/reports/">Reports Overview</a></li>
#                             <li><a href="javascript:;" onclick="tflink('https://www.trailforks.com/reports/all/?nearby_range=50&amp;near=point&amp;lat=51.496398925781&amp;lng=-0.12240000069141')">Nearby Reports</a></li>
#                             <li><a href="https://www.trailforks.com/reports/all/?viewMode=list&work=1&hasphoto=1">Trail Work Photos</a></li>
#                             <li class="yellow"><a href="https://www.trailforks.com/contribute/report/" rel="nofollow">Submit Report</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                                 <li id="menu_parks" class="overflow">
#                     <a href="javascript:;" class="parent drop2 ">Parks<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 160px;">
#                         <ul>
#                                                                                             <li><a href="https://www.trailforks.com/bikeparks/">Bike Parks</a></li>
#                                                                                                 <li><a href="https://www.trailforks.com/skillparks/">Skill Parks</a></li>
#                                                                                         <li><a href="https://www.trailforks.com/ridingareas/">Riding Areas</a></li>
#                                                     </ul>
#                     </div>
#                 </li>
#                                 <li id="menu_ridelog">
#                     <a href="javascript:;" class="parent drop2 ">Ride Log<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="width: 150px;">
#                         <ul>
#                                                             <li><a href="https://www.trailforks.com/ridelog/">Ride Logs</a></li>
#                                                         <li><a href="https://www.trailforks.com/tools/roadtrip/">Road Trips</a></li>
#                             <li><a href="https://www.trailforks.com/ridelog/heatmap/">Heatmap</a></li>
#                             <li><a href="https://www.trailforks.com/badges/">Badges</a></li>
#                             <li class="yellow"><a href="https://www.trailforks.com/contribute/ridelog/" rel="nofollow">Add Ride Log</a></li>
#                                                                 <li style="background-color:#fc4c02;"><a href="https://www.trailforks.com/ridelog/stravaguide/">Connect Strava</a></li>
#                                                             </ul>
#                     </div>
#                 </li>
#                 <li id="menu_events" class="overflow">
#                     <a href="https://www.trailforks.com/events/" class="parent ">Events<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="min-width: 150px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/events/">Upcoming Events</a></li>
#                                                     </ul>
#                     </div>
#                 </li>
#                 <li id="menu_app" class="overflow">
#                     <a href="https://www.trailforks.com/apps/map/" class="parent ">Apps</a>
#                 </li>
#                 <li id="menu_more2" class="overflow">
#                     <a href="javascript:;" class="parent drop2">More<span class="opener">&nbsp;</span></a>
#                     <div class="submenu" style="min-width: 160px;">
#                         <ul>
#                             <li><a href="https://www.trailforks.com/directory/" class="">Directory</a></li>
#                             <li><a href="https://www.trailforks.com/tools/">Tools</a></li>
#                                                         <li><a href="https://www.trailforks.com/localproducts/">Products</a></li>
#                             <li><a href="https://www.trailforks.com/youtubechannels/">Youtube Channels</a></li>
#                                                         <li><a href="https://www.trailforks.com/photos/">Photos</a></li>
#                             <li><a href="https://www.trailforks.com/videos/">Videos</a></li>
#                             <li><a href="https://www.trailforks.com/statistics/">Stats</a></li>
#                             <li><a href="https://www.trailforks.com/karma/">Trail Karma</a></li>
#                             <li><a href="https://www.trailforks.com/blog/">Blog</a></li>
#                             <li><a href="https://www.trailforks.com/help/">Help</a></li>
#                             <li><a href="https://www.trailforks.com/about/">About</a></li>
#                             <li class="yellow"><a href="https://www.trailforks.com/contribute/">Contribute</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                 <li id="menu_more">
#                     <a href="javascript:;" class="parent drop2">More<span class="opener">&nbsp;</span></a>
#                     <div class="submenu">
#                         <ul class="makecols2">
#                             <li><span onclick="tflink('https://www.trailforks.com/apps/map/');">Apps</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/nearby/');">Nearby</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/reports/');">Reports</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/events/');">Events</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/photos/');">Photos</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/videos/');">Videos</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/skillparks/');">Skill Parks</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/directory/');">Directory</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/localproducts/');">Products</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/youtubechannels/');">Youtube Channels</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/tools/');">Tools</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/karma/');">Trail Karma</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/stats/');">Stats</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/help/');">Help</span></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/about/');">About</span></li>
#                             <li class="yellow"><span onclick="tflink('https://www.trailforks.com/contribute/');">Contribute</span></li>
#                                                     </ul>
#                     </div>
#                 </li>
#                 <li id="menu_pinkbike" class="floatright" onclick="tflink('https://www.pinkbike.com/');"></li>
#                             </ul>
#         </nav> <!-- /#navigation -->
#     </div>
# </div>        <div id="topblocks"></div>
#         <div id="content-container">
#
#             <div class="wrapper clearfix">
#                                                             </div>
#                         <div id="pageheader" class="wrapper clearfix">
#
#                                 <div class="breadcrumb"></div>
#
#
#
#                 <div id="tabs_wrapper"></div>
#             </div>
#
#             <a id="main-content"></a>
#             <div id="mainwrapper" class="wrapper clearfix">
#     <section role="main" id="main" class="col-12">
#         <style>
#     #loginHeader {
#         background-color: rgba(20, 20, 20, 0.6);
#         color: #fff;
#         padding: 10px 10px;
#
#         text-align: center;
#         width: auto;
#         max-width: 470px;
#         margin: 15px auto 0 auto;
#         float: 50%;
#     }
#     #loginHeader h1 {
#         margin: 0;
#         font-size: 2em;
#     }
#     @media screen and (min-width: 1024px) {
#         #container {
#             background-image: url("https://ep1.pinkbike.org/p6pb16045633/p6pb16045633.jpg");
#             background-size: cover;
#             background-position: 0 50px;
#         }
#         #loginform {
#             text-align: center;
#             width: auto;
#             max-width: 470px;
#             margin: 0 auto;
#             background-color: rgba(255, 255, 255, 0.9);
#             float: 50%;
#             padding: 10px;
#         }
#         #main {
#             clear: left;
#         }
#     }
# </style><div id="loginHeader" class="center">
#     <h1>Login to Trailforks</h1>
# </div>
# <div id="loginform">
#     <form class="formCustom " name="loginform" action="/wosFormCheck.php" method="post"  >
# <div><input type="hidden" name="ripformname" value="loginform" /></div><input type="hidden" name="formpage"  value="/login/#loginform" /> <input type="hidden" name="fieldstack[0]" value="source" /><input type="hidden" name="source-alpha"  value="trailforks"   />
#     <div class="center grey margin-top-10">
#         <img src="https://es.pinkbike.org/246/sprt/i/trailforks/pb_menu_logo.png" width="100" height="24" alt="Pinkbike logo" />
#         <p class="margin-top-10">
#             You can login to Trailforks with your <a href="https://www.pinkbike.com/">Pinkbike</a> account.
#             <br>
#             Don't have a login? <a href="https://www.trailforks.com/signup/" class="bold" rel="nofollow">Join now!</a>
#         </p>
#     </div>
#
#     <div class="center block">
#         <table class="block padded5" style="width: auto; margin: 0 auto;">
#             <tr>
#                 <td colspan="2">
#                     <label for="username" class="grey">Email or Username</label>
#                     <br>
#                     <input type="hidden" name="fieldstack[1]" value="username" /><input type="text" name="username-login-loginlen" size="30" id="username"  autofocus="autofocus" placeholder="username" value=""/>                </td>
#             </tr>
#             <tr>
#                 <td colspan="2">
#                     <label for="password" class="grey">Password:</label>
#                     <br>
#                     <input type="hidden" name="fieldstack[2]" value="password" /><input type="password" name="password-password-lt200" size="30" value="" id="password" placeholder="password" />                 </td>
#             </tr>
#             <tr>
#                 <td colspan="2"></td>
#             </tr>
#             <tr>
#                 <td><label for="rememberme">Remember me:</label></td>
#                                 <td><input type="hidden" name="fieldstack[3]" value="rememberme" /><input type="checkbox" name="rememberme" checked="checked"  id="rememberme" class="remembermeCheckbox" value=""/></td>
#             </tr>
#             <tr>
#                 <td><label for="logoutother">Logout all other devices:</label></td>
#                 <td><input type="hidden" name="fieldstack[4]" value="logoutother" /><input type="checkbox" name="logoutother" id="logoutother"  value=""/></td>
#             </tr>
#             <tr>
#                 <td colspan="2"></td>
#             </tr>
#             <tr>
#                 <td colspan="2">
#                     <input type="submit" name="submitbutton['Login']" style="width:100%;" value="Login" onclick="if(typeof(wO) !== 'undefined') { return false; } else { wO=1;return true;}" /><input type="hidden" name="buttondest['Login']" value="https://www.trailforks.com/x_login_form/" />                 </td>
#             </tr>
#         </table>
#     </div>
#
#
#
#
#     <div class="center block grey">
#         <a href="https://www.trailforks.com/forgotpassword/" class="underline" rel="nofollow">Forgot login/password info?</a>
#     </div>
#
#     <input type="text" name="iebug" value="1" style="display:none" /><input type="hidden" name="formhash" value="+t9UzozVkiKVu3yg/RbklGo2Su8WVKanISB/QEvQdSsfy7wOCko4sQmpAUAaEenuCtrppk0Lw/0IguC/gCgPKJlwvypxWL1jn3pBzTE=" autocomplete="off" /></form></div>            </section>
# </div>        </div>
#         <div class="clear"></div>
#     </div> <!-- /#container2 -->
# </div> <!-- /#container -->
# <div id="map_header"></div>
# <footer>
#     <div id="container_footer" class="">
#
#         <div id="footer_mountains"></div>
#
#         <div id="footer">
#             <div class="wrapper">
#                 <div class="inner clearfix">
#                     <div id="footer1" class="col-4" itemscope itemtype="http://schema.org/Organization">
#                         <link itemprop="url" href="https://www.trailforks.com/">
#                         <link itemprop="logo" href="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_avatar.png">
#                         <ul class="inline">
#                             <li><div id="fblikebox" class="tablet_hide"></div></li>
#                             <li><a href="https://www.facebook.com/trailforks" itemprop="sameAs" target="_blank" rel="noopener" data-icon="&#xe601;" class="larger white" title="Trailforks Facebook Page"></a></li>
#                             <li><a href="https://twitter.com/trailforks" itemprop="sameAs" target="_blank" rel="noopener" data-icon="&#xe602;" class="larger white" title="Trailforks Twitter"></a></li>
#                             <li><a href="https://www.instagram.com/trailforks/" itemprop="sameAs" target="_blank" rel="noopener" data-icon="&#xea92;" class="larger white" title="Trailforks Instagram"></a></li>
#                         </ul>
#                                                     <br>
#                             <a href="https://www.trailforks.com/pro/?source=footer" class="getpro withproicon" style="color: #ffcd05; margin-left: 0;">Get Trailforks PRO</a>
#                                             </div>
#
#                     <div id="footer2" class="col-4 clearfix">
#                         <ul class="padded5 floatleft">
#                             <li><a href="https://www.trailforks.com/about/">About</a></li>
#                             <li><a href="https://www.trailforks.com/about/contact/">Contact</a></li>
#                             <li><a href="https://www.trailforks.com/about/legal/">Privacy Policy</a></li>
#                             <li><span onclick="tflink('https://www.trailforks.com/signup/')" class="footerlink clickable">Sign Up!</span></li>
#                         </ul>
#
#                         <ul class="padded5 floatleft" style="margin-left: 20px;">
#                             <li><a href="https://www.trailforks.com/apps/map/">Apps</a></li>
#                             <li><a href="https://www.trailforks.com/blog/">Blog</a></li>
#                             <li><a href="https://www.trailforks.com/widgets/">Widgets</a></li>
#                             <li><a href="https://www.trailforks.com/sitemap/">Sitemap</a></li>
#                         </ul>
#
#                         <ul class="padded5 floatleft" style="margin-left: 20px;">
#                             <li><a href="https://m.trailforks.com/" rel="nofollow">Mobile Site</a></li>
#                             <li><a href="https://www.trailforks.com/tools/">Tools</a></li>
#                             <li><a href="https://www.pinkbike.com/forum/trailforks-feedback/">Support Forum</a></li>
#                             <li><a href="https://www.trailforks.com/help/">Help</a></li>
#                         </ul>
#                     </div>
#
#                     <div id="footer3" class="col-4 last small grey">
#                         <a href="https://www.trailforks.com/apps/map/"><img data-src="https://es.pinkbike.org/246/sprt/i/trailforks/banners/trailforks_app_footer.png" class="lazyload" alt="Trailforks mobile app" width="320" height="83" id="app_banner" /></a>
#                         <div id="copyright">
#                             <span class="opaque30">0.011927 ms</span>
#                             <br />
#                             Copyright &copy; 2020. Trailforks Mapping Inc. All rights reserved.
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </footer>        <script src="https://es.pinkbike.org/0326454c564a73/sprt/j/trailforks/trailforks.min.js"  crossorigin></script>
#         <script>(function() {
#
# pb.addEvent("#menu_nearby","mouseover",function fn1(e) {
#   pb.trail.nearby_menu();
# });
# })();</script>
#
# <div id="login-info">
#     <div class="tooltip-container" style="visibility: visible;" id="pbtooltip">
#         <div class="tooltip">
#             <span onclick="pb.box.close()" class="clickable"><span class="close-it"></span></span>
#             <div class="tooltip-body" id="pbtooltipbody">
#                 <div class="tooltip-header">You must login to Trailforks.</div>
#                 <br />
#                 <span onclick="tflink('https://www.pinkbike.com/user/signup/')" class="button1 green">Join Pinkbike</span>&nbsp;&nbsp;<span onclick="tflink('https://www.pinkbike.com/user/login/')" class="button1">Login</span>
#             </div>
#         </div>
#     </div>
# </div>
#
# </body>
# </html>

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n<title>Error</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<meta property="og:image" content="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_avatar.png"/>\n<meta property="og:site_name" content="Trailforks" />\n<meta property="fb:app_id" content="158879950980488" />\n<meta property="fb:admins" content="517713210" />\n<meta name="application-name" content="Trailforks" />\n<meta name="apple-itunes-app" content="app-id=987986743" />\n<meta name="theme-color" content="#fec200"/>\n<link rel="manifest" href="/manifest.json">\n<link rel="dns-prefetch" href="//es.pinkbike.org" />\n<link rel="dns-prefetch" href="//ep1.pinkbike.org" />\n<link rel="dns-prefetch" href="//ep2.pinkbike.org" />\n<link rel="dns-prefetch" href="//ep3.pinkbike.org" />\n<link rel="dns-prefetch" href="//ep4.pinkbike.org" />\n<link rel="dns-prefetch" href="//gis.pinkbike.org" />\n<link rel="publisher" href="https://plus.google.com/+Trailforksapp/" />\n<link rel="shortcut icon" href="https://es.pinkbike.org/246/sprt/i/trailforks/favicon.ico" />\n<link rel="apple-touch-icon" href="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_icon_120x120.png" />\n<link rel="apple-touch-icon-precomposed" href="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_icon_120x120p.png" />\n        <link rel="stylesheet" href="https://es.pinkbike.org/63d80940ad/sprt/c/trailforks/_common-min.css"/>\n        <script src="https://es.pinkbike.org/032616ad06c5ac/sprt/j/jquery.min.js"  crossorigin></script>\n                <script type="text/javascript">\n        var _trackJs = { \n            customer: \'d979e0ee0b27484c936d70bfdc85dd4e\'\n        };\n        var pbwww="https://www.trailforks.com/";\n        var pbxv="https://ev1.pinkbike.org/";\n        var pbdomain="trailforks.com";\n        var pbcs="https://es.pinkbike.org/246/sprt/i/";\n        var pbjs="https://es.pinkbike.org/326/sprt/j/";\n        var pbcookiedomain=".trailforks.com";\n        var pbuid=\'0\';\n        </script>\n                <script src="https://es.pinkbike.org/0326779e00d23d/sprt/j/pblib.js"  crossorigin></script>\n                <script src="https://es.pinkbike.org/0326060dcf1c39/sprt/j/jquery-ui-1.10.3.custom.min.js"  crossorigin></script>\n        \n<script>\nwindow.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;\nga(\'create\', {\n  trackingId: \'UA-2380007-4\',\n  cookieDomain: \'trailforks.com\'\n});\nga(\'send\', \'pageview\');\n</script>\n\n<script async src=\'https://www.google-analytics.com/analytics.js\'></script>\n</head>\n<body id="top" class=" admin_debug">\n<a class="none" href="#content-container">[Skip to Content]</a>\n\n<div id="container">\n    <div id="container2">\n                    <div id="headerwrapper">\n        <div class="wrapper">\n            <header id="header" class="clearfix">\n                <a href="https://www.trailforks.com/" id="logo">\n                    <img src="https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_logo_vector_2color.svg" onerror="this.onerror=null; this.src=\'https://es.pinkbike.org/246/sprt/i/trailforks/trailforks_logo_sign.png\'" alt="Trailforks" width="227" height="35" />\n                </a>\n                <div id="header_left">\n                                        <div id="activitytype_menu" class="hovertip" title="Mountain Bike" onclick="ga(\'send\', \'event\', \'activitytype\', \'header\');">\n                        <div class="parent clickable grey" data-featherlight="https://www.trailforks.com/change_activitytype/?popup=1">\n                             <span aria-hidden="true" data-icon="&#xe90c;" class="activityIcon" title="Mountain Bike" style="color: #29691f;"></span>                             <span class="mobile_hide">Mountain Bike</span> <span class="openarrow">&nbsp;</span>\n                        </div>\n         ...
